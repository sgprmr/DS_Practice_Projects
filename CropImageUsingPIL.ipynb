# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import ndimage, misc
from PIL import Image
import os

# %%
pic = Image.open('./Test_pic.PNG')

# %%
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x1200 at 0x1682F4F23C8>

# %%
pic.rotate(30, expand="20", fillcolor="Blue")
# Out:
# <PIL.Image.Image image mode=RGBA size=1640x1640 at 0x1682F5B19B0>

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 4))
ax = axes.ravel()

ax[0].imshow(pil_im)
ax[0].set_title("Original")
ax[1].imshow(cropImage)
ax[1].set_title("CropImage")

fig.tight_layout()
plt.show()
